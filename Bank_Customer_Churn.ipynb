# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamtapadia/DataScience_Stuff/blob/main/Bank_Customer_Churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#get data read data
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
df=pd.read_csv('/gdrive/MyDrive/DataScience_Stuff/Churn_Modelling.csv')
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Gender'].replace({'Male':1, 'Female':0}, inplace=True)
df.Gender.unique()
# Out:
# array([0, 1])

# %%
df.Geography.unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France       0   42
# 1          2    15647311      Hill          608     Spain       0   41
# 2          3    15619304      Onio          502    France       0   42
# 3          4    15701354      Boni          699    France       0   39
# 4          5    15737888  Mitchell          850     Spain       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
#My Strategy
# 1.Read data, Understand data
# As per my understanding start with column 1 RowNumber which nort required
# Column 2 Customer ID not required
# Column 3 Surname not required
# We have to remove thise above columns
# Creditscore required data type is int so nothis to change ( check extra ordi nary values )
# Geography as we can see there are three  'France', 'Spain', 'Germany' geographical location we have
# Gender I already converted that M to 1 and F to 0 and data type is int
# Age datat type is int no issue for that as well ( check extra ordi nary values )
# Tenure is int so no issue ( check extra ordi nary values )
# Balance float no issue ( check extra ordi nary values )
# No of product int ( check extra ordi nary values )
# has credit int no issue as well ( check extra ordi nary values )
# Is Active member int no issue as well ( check extra ordi nary values )
# Estimated salary  float ( check extra ordi nary values )
# Exited int ( check extra ordi nary values )
# Overcome with that extra orfdinary values 
# create dummy values for that geography column
# compaire exited with geo
# compaire exited with gender
# compaire exited with Age
# compaire exited with Balance
# compaire exited with No of product
# compaire exited with has credit card
# compaire exited with is active 
# Let see what is next

# %%
df.Age.unique()
# Out:
# array([42, 41, 39, 43, 44, 50, 29, 27, 31, 24, 34, 25, 35, 45, 58, 32, 38,
#        46, 36, 33, 40, 51, 61, 49, 37, 19, 66, 56, 26, 21, 55, 75, 22, 30,
#        28, 65, 48, 52, 57, 73, 47, 54, 72, 20, 67, 79, 62, 53, 80, 59, 68,
#        23, 60, 70, 63, 64, 18, 82, 69, 74, 71, 76, 77, 88, 85, 84, 78, 81,
#        92, 83])

# %%
df.Tenure.unique()
# Out:
# array([ 2,  1,  8,  7,  4,  6,  3, 10,  5,  9,  0])

# %%
df.Balance.unique()
# Out:
# array([     0.  ,  83807.86, 159660.8 , ...,  57369.61,  75075.31,
#        130142.79])

# %%
df.NumOfProducts.unique()
# Out:
# array([1, 3, 2, 4])

# %%
df.HasCrCard.unique()
# Out:
# array([1, 0])

# %%
df.IsActiveMember.unique()
# Out:
# array([1, 0])

# %%
df.Exited.unique()
# Out:
# array([1, 0])

# %%
df.CreditScore.unique()
# Out:
# array([619, 608, 502, 699, 850, 645, 822, 376, 501, 684, 528, 497, 476,
#        549, 635, 616, 653, 587, 726, 732, 636, 510, 669, 846, 577, 756,
#        571, 574, 411, 591, 533, 553, 520, 722, 475, 490, 804, 582, 472,
#        465, 556, 834, 660, 776, 829, 637, 550, 698, 585, 788, 655, 601,
#        656, 725, 511, 614, 742, 687, 555, 603, 751, 581, 735, 661, 675,
#        738, 813, 657, 604, 519, 664, 678, 757, 416, 665, 777, 543, 506,
#        493, 652, 750, 729, 646, 647, 808, 524, 769, 730, 515, 773, 814,
#        710, 413, 623, 670, 622, 785, 605, 479, 685, 538, 562, 721, 628,
#        668, 828, 674, 625, 432, 770, 758, 795, 686, 789, 589, 461, 584,
#        579, 663, 682, 793, 691, 485, 650, 754, 535, 716, 539, 706, 586,
#        631, 717, 800, 683, 704, 615, 667, 484, 480, 578, 512, 606, 597,
#        778, 514, 525, 715, 580, 807, 521, 759, 516, 711, 618, 643, 671,
#        689, 620, 676, 572, 695, 592, 567, 694, 547, 594, 673, 610, 767,
# ...

# %%
# As per my understanding start with column 1 RowNumber which nort required
# Column 2 Customer ID not required
# Column 3 Surname not required

# %%
df1=df.drop(['RowNumber','CustomerId','Surname'], axis='columns')
df1.head(10)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
# 5          645     Spain       1   44       8  113755.78              2
# 6          822    France       1   50       7       0.00              2
# 7          376   Germany       0   29       4  115046.74              4
# 8          501    France       1   44       4  142051.07              2
# 9          684    France       1   27       2  134603.88              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# ...

# %%
df1.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender               int64
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
#Have to make dummy values of geo
df2 = pd.get_dummies(data=df1, columns=['Geography'])
df2.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0               1        101348.88       1                 1
# 1               1        112542.58       0                 0
# 2               0        113931.57       1                 1
# 3               0         93826.63       0                 1
# 4               1         79084.10       0                 0
#
#    Geography_Germany  Geography_Spain
# 0                  0                0
# 1                  0                1
# 2                  0                0
# ...

# %%
df2.dtypes
# Out:
# CreditScore            int64
# Gender                 int64
# Age                    int64
# Tenure                 int64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Exited                 int64
# Geography_France       uint8
# Geography_Germany      uint8
# Geography_Spain        uint8
# dtype: object

# %%
# Visualize data
import matplotlib.pyplot as plt

people_exit_dataset= df2[df2.Exited==1]
people_exit_dataset.shape
# Out:
# (2037, 13)

# %%
Loyal_People_Dataset= df2[df2.Exited==0]
Loyal_People_Dataset
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 1             608       0   41       1   83807.86              1          0
# 3             699       0   39       1       0.00              2          0
# 4             850       0   43       2  125510.82              1          1
# 6             822       1   50       7       0.00              2          1
# 8             501       1   44       4  142051.07              2          0
# ...           ...     ...  ...     ...        ...            ...        ...
# 9993          644       1   28       7  155060.41              1          1
# 9994          800       0   29       2       0.00              2          0
# 9995          771       1   39       5       0.00              2          1
# 9996          516       1   35      10   57369.61              1          1
# 9999          792       0   28       4  130142.79              1          1
#
# ...

# %%
from google.colab import files
df2.to_csv("Bank_Costomer_Churn.csv", index=False)
files.download('Bank_Costomer_Churn.csv')

# %%
# All Visualization is done in POWER BI

# %%
#Now we have to scale the data
#Here we can see lots of column that we have to scale ['EstimatedSalary','Balance','CreditScore']

# %%
col_to_scale=['EstimatedSalary','Balance','CreditScore','Tenure','NumOfProducts']

#we have to take minmax scalerfromsklear it will convert value to 0 and 1

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
df2[col_to_scale]=scaler.fit_transform(df2[col_to_scale])
df2=df2.drop('Age',axis='columns')
df2
# Out:
#       CreditScore  Gender  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0           0.538       0     0.2  0.000000       0.000000          1
# 1           0.516       0     0.1  0.334031       0.000000          0
# 2           0.304       0     0.8  0.636357       0.666667          1
# 3           0.698       0     0.1  0.000000       0.333333          0
# 4           1.000       0     0.2  0.500246       0.000000          1
# ...           ...     ...     ...       ...            ...        ...
# 9995        0.842       1     0.5  0.000000       0.333333          1
# 9996        0.332       1     1.0  0.228657       0.000000          1
# 9997        0.718       0     0.7  0.000000       0.000000          0
# 9998        0.844       1     0.3  0.299226       0.333333          1
# 9999        0.884       0     0.4  0.518708       0.000000          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# ...

# %%
x=df2.drop('Exited',axis='columns')
y=df2.Exited

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2,random_state=5)

# %%
x_train.shape
# Out:
# (8000, 11)

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(11, input_shape=(11,), activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

#Loss is binary creoss entropy bcz we have 0 & 1 value of output
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6158 - accuracy: 0.6579
# Epoch 2/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4894 - accuracy: 0.7960
# Epoch 3/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4818 - accuracy: 0.7950
# Epoch 4/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4783 - accuracy: 0.7936
# Epoch 5/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4758 - accuracy: 0.7945
# Epoch 6/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4739 - accuracy: 0.7955
# Epoch 7/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4730 - accuracy: 0.7951
# Epoch 8/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.7955
# Epoch 9/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.7951
# Epoch 10/100
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 63/63 [==============================] - 1s 6ms/step - loss: 0.4057 - accuracy: 0.8235
# [0.4057046175003052, 0.8234999775886536]

# %%
yp=model.predict(x_test)
yp[0:5]
# Out:
# array([[0.06457016],
#        [0.13069022],
#        [0.12686893],
#        [0.20113432],
#        [0.08746955]], dtype=float32)

# %%
y_pred =[]

for element in yp:
  if element >0.5:
    y_pred.append(1)
  else:
    y_pred.append(0)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      1595
#            1       0.64      0.30      0.40       405
#
#     accuracy                           0.82      2000
#    macro avg       0.74      0.63      0.65      2000
# weighted avg       0.80      0.82      0.80      2000

# %%
import seaborn as sn
cm= tf.math.confusion_matrix(labels=y_test, predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
