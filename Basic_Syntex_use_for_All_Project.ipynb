# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read File ::
# df=pd.read_csv("full Path file seperated with "/" backwordslash ")
# df= pd.read_csv("E:/Data Scientist/You Tube/20221227_Email_Spam/1.Download/spam.csv", encoding="ISO-8859-1")
# _____________________________________________________________________________________
#
# Read all txt,csv file at a time from folder ::
# from glob import glob
# filename=glob("full Path file seperated with "/" backwordslash  /names/*.txt")
#
# _____________________________________________________________________________________
#
# Concat Two data frames ::
# pd.concat(objs=[df_1, df_2])
# pd.concat(objs=[df_1,df_2], axis = 0, keys=[1880,1881], names=['Year']).droplevel(1).reset_index()
#
# _____________________________________________________________________________________
#
# Know more about data ::
# df.info()
#
# Column Name change ::
# df2.rename(columns = {"Close":"DJI_Close", "Return":"DJI_Return"}, inplace = True)
# _____________________________________________________________________________________
#
# Data type conversion ::
# Direct conversion :
# df_main.popularity = pd.to_numeric(df_main.popularity , errors = "coerce")
# df_main.popularity.dtype
#
#
# Normal Conversion :
# df['Date']=pd.to_datetime(df['Date'])
# df_main.popularity= df_main.popularity.astype('float')
#
# //If we get error bcz if there are some alfa numeric (a123, ab2) element then
# df_main.popularity = pd.to_numeric(df_main.popularity , errors = "coerce")
# df_main.popularity.dtype
#
#
# _____________________________________________________________________________________
#
# Set Index ::
# df.set_index('Date', inplace=True)
# _____________________________________________________________________________________
#
# Drop Unwanted Data ::
# df.drop(columns=['Col_Name_1', 'Col_Name_2'],  axis=1, inplace=True)   || || ||
# Check isna function ::
# df.isna().sum() (//This will provide you list of columns with respective no of NA values)  || || ||
# After finding NA values in columns display data having NA values ::
# na_values_in_col=df.total_bedrooms.isna()
# df.loc[na_values_in_col]  || || ||
# Now Droping NA columns :: df.dropna(inplace=True)
# _____________________________________________________________________________________
#
# #If you check any duplicates ::
# df[df.duplicated()]
# _____________________________________________________________________________________
#
# #Describe the perticular column like unique data , counts ::
# df.ocean_proximity.describe() || || ||
# #If you need more details then ::
# df.ocean_proximity.value_counts()
# _____________________________________________________________________________________
#
# #below code describe all data in graphical view ::
# df.hist(bins=50)
# plt.gcf().set_size_inches(20, 8)
# plt.show()
#
# At a time multiple
# df2[["DJI_Close", "Strategy"]].plot(fontsize = 15)
# plt.title("Simple Momentum Strategy", fontsize = 20)
# plt.legend(fontsize = 15)
# plt.gcf().set_size_inches(25,10)
# plt.show()
# _____________________________________________________________________________________
#
# #Check the corelation between columns
# df.corr()  ||
# df.corr().milestone_column_name.sort_values(ascending=False)
#
# _____________________________________________________________________________________
#
# #Simple hist
# df.median_income.hist(bins=100)
# plt.gcf().set_size_inches(10,5)
# plt.show()
#
# #Advance
# sns.jointplot(data = df, x = "median_income", y = "median_house_value", kind = "reg")
# plt.gcf().set_size_inches(10,5)
# plt.show()
#
# #Super advance
# df.plot(kind="scatter", x="longitude", y="latitude",
#                        s=df.population/100, label="Population", figsize = (15, 10),
#                        c="median_house_value", cmap= "coolwarm",
#                        colorbar=True, alpha=0.4, fontsize = 15, sharex = False)
# plt.ylabel("Latitude", fontsize=14)
# plt.xlabel("Longitude", fontsize=14)
# plt.legend(fontsize=16)
# plt.show()
#
# -------------------------------------------------------------
#
# plt.figure(figsize=(8, 8))
# plt.subplot(1, 2, 1)
# plt.plot(range(20), acc, label='Training Accuracy')
# plt.plot(range(20), val_acc, label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')
#
# plt.subplot(1,2,2)
# plt.plot(range(20), loss, label="Training Loss")
# plt.plot(range(20), val_loss, label="Validation Loss")
# plt.legend(loc='lower left')
# plt.title('Training and Validation Loss')
#
# plt.show()
#
# _____________________________________________________________________________________
#
# #df.median_income -> min=0.49, max=15.00 below code is break 0.49 to 15.00 6 pices acco to (0, 0.25, 0.5, 0.75, 0.95, 1)
# pd.qcut(df.median_income, q = [0, 0.25, 0.5, 0.75, 0.95, 1])
# after break them into the pices lable them
# df["income_cat"] = pd.qcut(df.median_income, q = [0, 0.25, 0.5, 0.75, 0.95, 1],labels = ["Low", "Below_Average", "Above_Average", "High", "Very High"])
# df
# _____________________________________________________________________________________
#
# #Data type conversion
# df.select_dtypes("float")
#
# df_main.popularity= df_main.popularity.astype('float')
# df_main.popularity.dtype
# or
# df_main.popularity = pd.to_numeric(df_main.popularity , errors = "coerce")
# df_main.popularity.dtype
#
# _____________________________________________________________________________________
#
# #Standerdization
#
# df1 = df.select_dtypes("float").apply(lambda x: stats.zscore(x))
#
# _____________________________________________________________________________________
#
# #One hot encoding
# dummies = pd.get_dummies(features.ocean_proximity)
# data_df = data_df.add(dummies, axis='columns') or
# data_with_dummies = pd.concat([data_for_dummy,dummies ], axis=1)
# data_with_dummies.drop('Company', inplace=True, axis=1)
# data_with_dummies
#
# _____________________________________________________________________________________
# #Mapping
# dict1={ 'Air Asia': 2,
#  'Air India': 7,
#  'GoAir': 4,
#  'IndiGo': 3,
#  'Jet Airways': 10,
#  'Jet Airways Business': 11,
#  'Multiple carriers': 8,
#  'Multiple carriers Premium economy': 9,
#  'SpiceJet': 1,
#  'Trujet': 0,
#  'Vistara': 5,
#  'Vistara Premium economy': 6}
#
#
# data['Airline']= data['Airline'].map(dict1)
#
#
#
#   ----------------------------------------------------
#
#
# date_lst=[]
# for i in df.Journey_month:
#     date_lst.append(i)
#
# sessions={ 'Winter':[11,12,1,2],
#          'Summer': [3,4,5,6],
#          'Rain' :[7,8,9,10]}
#
# #We took 2 for loop 1st is for date_lst and 2nd is for session then we take one if condition to check and get key value from it
#
# sesson_date=[key for i in date_lst for key, val in sessions.items() if i in val]
#
# sesson_date
#
# ____________________________________________________________________________________
#
# ## Algorithums
#
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2)
#
# from sklearn.linear_model import LogisticRegression
# lr_model=LogisticRegression()
#
# from sklearn.ensemble import RandomForestClassifier
# rf_model=RandomForestClassifier()
#
# from sklearn.svm import SVC
# svc_model=SVC()
#
# from sklearn.tree import DecisionTreeClassifier
# t_model=DecisionTreeClassifier()
#
# from sklearn.neighbors import KNeighborsClassifier
# knn_model=KNeighborsClassifier(n_neighbors=10)
#
# -------------------------------------------------------------
# def model_score(models):
#     #print(models)
#     model=models()
#     #print(model)
#     models.fit(x_train, y_train)
#     return models.score(x_test,y_test)
#
# models=({
#     'Random_Forest' : RandomForestClassifier,
#     'SVM' : SVC,
#     'Decision_Tree' : DecisionTreeClassifier,
#     'Logistic_Regression' : LogisticRegression,
#     'KNN' : KNeighborsClassifier
# })
#
# for keys, data in models.items():
#     model=data()
#     result=model_score(model)
#     print(str(keys)+ " : "+ str(result) )
#
# -------------------------------------------------------------
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import AdaBoostClassifier
# from sklearn.ensemble import BaggingClassifier
# from sklearn.ensemble import ExtraTreesClassifier
# from sklearn.ensemble import GradientBoostingClassifier
# from xgboost import XGBClassifier
#
# svc = SVC(kernel='sigmoid', gamma=1.0)
# knc = KNeighborsClassifier()
# mnb = MultinomialNB()
# dtc = DecisionTreeClassifier(max_depth=5)
# lrc = LogisticRegression(solver='liblinear', penalty='l1')
# rfc = RandomForestClassifier(n_estimators=50, random_state=2)
# abc = AdaBoostClassifier(n_estimators=50, random_state=2)
# bc = BaggingClassifier(n_estimators=50, random_state=2)
# etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
# gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
# xgb = XGBClassifier(n_estimators=50,random_state=2)
#
# clfs = {
#     'SVC' : svc,
#     'KN' : knc,
#     'NB': mnb,
#     'DT': dtc,
#     'LR': lrc,
#     'RF': rfc,
#     'AdaBoost': abc,
#     'BgC': bc,
#     'ETC': etc,
#     'GBDT':gbdt,
#     'xgb':xgb
# }
#
# def train_classifier(clf,X_train,y_train,X_test,y_test):
#     clf.fit(X_train,y_train)
#     y_pred = clf.predict(X_test)
#     accuracy = accuracy_score(y_test,y_pred)
#     precision = precision_score(y_test,y_pred)
#
#     return accuracy,precision
#
#
#
# accuracy_scores = []
# precision_scores = []
#
# for name,clf in clfs.items():
#
#     current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
#
#     print("For ",name)
#     print("Accuracy - ",current_accuracy)
#     print("Precision - ",current_precision)
#
#     accuracy_scores.append(current_accuracy)
#     precision_scores.append(current_precision)

# %% [markdown]
# ### Data Cleaning
#
# ##### Filtering only str values from  columns
# data[data['cl_nam'].str.isnumeric()]
# data['cl_name']=data['cl_name'].astype(int) //Convert col-dtype to int
# ##### column exclue with typical value here that value is "xyz"
# data=data[data['cl_name']!="xyz"]
# ##### if we have price in the form of 20,000 and we want 20000 then replace "," with ""
# data['Price']=data['Price'].str.replace(",","").astype(int)
# #####  If we have data linke this 45,000 kms and we want this 45000 only then 1st replace "," with " " then
# data['kms_driven']=data['kms_driven'].str.replace(",","")
# data['kms_driven'].str.split(" ").str.get(0)  ### or ###
# data['kms_driven'].str.split(" ").str.get(0).str.replace(",","") //Single line code
# ##### to get those values who has na values
# data[data['fuel_type'].isna()]
# //excuding those na values remaning data
# data[~data['fuel_type'].isna()]
#
# ##### keep 3 words of sentence from column like : "Hyundai Santro Xing" from "Hyundai Santro Xing XO eRLX Euro III"
# data['name'].str.split(" ").str.slice(0,3).str.join(" ")  //If some onew have not first 3 word still it automatically take what ever they have.

# %%
#At a time read all data in folder
from glob import glob
filename=glob("E:/Data Scientist/Udemy/12Advance Projects/20221102AllData/Section7/Project_06_Materials/Project_06_Materials/names/*.txt")

dataframe=[]
for name in filename:
    data=pd.read_csv(name, header=None, names=["Name","Gender","Year","State", "count"])
    dataframe.append(data)

dataframe
# Out:
# [           Name Gender  Year  State  count
#  0          Mary      F  7065    NaN    NaN
#  1          Anna      F  2604    NaN    NaN
#  2          Emma      F  2003    NaN    NaN
#  3     Elizabeth      F  1939    NaN    NaN
#  4        Minnie      F  1746    NaN    NaN
#  ...         ...    ...   ...    ...    ...
#  1995     Woodie      M     5    NaN    NaN
#  1996     Worthy      M     5    NaN    NaN
#  1997     Wright      M     5    NaN    NaN
#  1998       York      M     5    NaN    NaN
#  1999  Zachariah      M     5    NaN    NaN
#
#  [2000 rows x 5 columns],
#             Name Gender  Year  State  count
#  0          Mary      F  6919    NaN    NaN
#  1          Anna      F  2698    NaN    NaN
#  2          Emma      F  2034    NaN    NaN
#  3     Elizabeth      F  1852    NaN    NaN
#  4      Margaret      F  1658    NaN    NaN
#  ...         ...    ...   ...    ...    ...
#  1930     Wiliam      M     5    NaN    NaN
#  1931     Wilton      M     5    NaN    NaN
# ...

# %%
#Concat
df= pd.concat(dataframe, ignore_index=True )
df

#General concat
pd.concat(objs=[df_1, df_2])
pd.concat(objs=[df_1,df_2], axis = 0, keys=[1880,1881], names=['Year']).droplevel(1).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11488\2379100275.py in <module>
#       4
#       5 #General concat
# ----> 6 pd.concat(objs=[df_1, df_2])
#       7 pd.concat(objs=[df_1,df_2], axis = 0, keys=[1880,1881], names=['Year']).droplevel(1).reset_index()
#
# NameError: name 'df_1' is not defined

# %%
df=pd.read_csv("E:/Data Scientist/Udemy/12Advance Projects/20221102AllData/Section9/Project_08_Materials/Project_08_Materials/housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
#df.drop(columns=['longitude', 'latitude'],  axis=1, inplace=True)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
na_values_in_col=df.total_bedrooms.isna()
df.loc[na_values_in_col]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %%
df.ocean_proximity.describe()
# Out:
# count         20433
# unique            5
# top       <1H OCEAN
# freq           9034
# Name: ocean_proximity, dtype: object

# %%
df.hist(bins=50)
plt.gcf().set_size_inches(20, 8)
plt.show()

# %%
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# ...

# %%
#we take "median_house_value" as mile stone 
df.corr().median_house_value.sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688355
# total_rooms           0.133294
# housing_median_age    0.106432
# households            0.064894
# total_bedrooms        0.049686
# population           -0.025300
# longitude            -0.045398
# latitude             -0.144638
# Name: median_house_value, dtype: float64

# %%
#Basic hist
df.median_income.hist(bins=100)
plt.gcf().set_size_inches(10,5)
plt.show()

# %%
sns.jointplot(data = df, x = "median_income", y = "median_house_value", kind = "reg")
#sns.jointplot(data = df, x = "median_income", y = "median_house_value", kind = "kde")
#sns.jointplot(data = df, x = "median_income", y = "median_house_value", kind = "scatter")
#sns.jointplot(data = df, x = "median_income", y = "median_house_value", kind = "hex")
plt.gcf().set_size_inches(10,5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5376\547459584.py in <module>
# ----> 1 sns.jointplot(data = df, x = "median_income", y = "median_house_value", kind = "reg")
#       2 #sns.jointplot(data = df, x = "median_income", y = "median_house_value", kind = "kde")
#       3 #sns.jointplot(data = df, x = "median_income", y = "median_house_value", kind = "scatter")
#       4 #sns.jointplot(data = df, x = "median_income", y = "median_house_value", kind = "hex")
#       5 plt.gcf().set_size_inches(10,5)
#
# NameError: name 'sns' is not defined

# %%
df.plot(kind="scatter", x="longitude", y="latitude",
                       s=df.population/100, label="Population", figsize = (15, 10),
                       c="median_house_value", cmap= "coolwarm",
                       colorbar=True, alpha=0.4, fontsize = 15, sharex = False)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend(fontsize=16)
plt.show()

# %%
df.median_income.describe()
# Out:
# count    20433.000000
# mean         3.871162
# std          1.899291
# min          0.499900
# 25%          2.563700
# 50%          3.536500
# 75%          4.744000
# max         15.000100
# Name: median_income, dtype: float64

# %%
#df.median_income -> min=0.49, max=15.00 below code is break 0.49 to 15.00 6 pices acco to (0, 0.25, 0.5, 0.75, 0.95, 1)

pd.qcut(df.median_income, q = [0, 0.25, 0.5, 0.75, 0.95, 1])
# Out:
# 0           (7.3, 15.0]
# 1           (7.3, 15.0]
# 2          (4.744, 7.3]
# 3          (4.744, 7.3]
# 4        (3.536, 4.744]
#               ...
# 20635    (0.499, 2.564]
# 20636    (0.499, 2.564]
# 20637    (0.499, 2.564]
# 20638    (0.499, 2.564]
# 20639    (0.499, 2.564]
# Name: median_income, Length: 20433, dtype: category
# Categories (5, interval[float64, right]): [(0.499, 2.564] < (2.564, 3.536] < (3.536, 4.744] < (4.744, 7.3] < (7.3, 15.0]]

# %%
df["income_cat"] = pd.qcut(df.median_income, q = [0, 0.25, 0.5, 0.75, 0.95, 1],labels = ["Low", "Below_Average", "Above_Average", "High", "Very High"])
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
features = df.drop(columns = ["median_house_value"])
features
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
features.select_dtypes("float")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income
# ...
