# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamtapadia/DataScience_Stuff/blob/main/UDeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy
# !pip install statsmodels
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
data = pd.read_csv("/gdrive/MyDrive/DataScience_Stuff/USimpleLR_1.csv")
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
plt.scatter(data.SAT,data.GPA)
plt.xlabel("SAT", fontsize=20)
plt.ylabel("GPA", fontsize=20)
plt.show()

# %% [markdown]
# **Formula** is  ***Y = b0 + b1x1***

# %%
Y = data.GPA
X1 = data.SAT

X0 = sm.add_constant(X1)
result = sm.OLS(Y,X0).fit()
#OLS Ordinary List square regression 
result.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Tue, 14 Jun 2022   Prob (F-statistic):           7.20e-11
# Time:                        06:36:30   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
# Create a scatter plot
plt.scatter(X1,Y)
# Define the regression equation, so we can plot it later
yhat = 0.0017*X1 + 0.275  # Y = b0 x0 + b1 x1     x0=1, b0=0.275 , x1, b1=0.0017 as per above tbl
# Plot the regression line against the independent variable (SAT)
plt.plot(X1,yhat, lw=1, c='orange', label ='regression line')
# Label the axes
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %% [markdown]
# Real Estate Example

# %%
Estate_Data = pd.read_csv("/gdrive/MyDrive/DataScience_Stuff/real_estate_price_size.csv")
Estate_Data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
Estate_Data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
# We are predict price via size
y = Estate_Data['size']
x1 = Estate_Data.price

y
# Out:
# 0      643.09
# 1      656.22
# 2      487.29
# 3     1504.75
# 4     1275.46
#        ...
# 95     549.80
# 96    1037.44
# 97    1504.75
# 98     648.29
# 99     705.29
# Name: size, Length: 100, dtype: float64

# %%
plt.scatter(x1,y)
plt.xlabel('Size',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.show()

# %%
X0 = sm.add_constant(x1)
result = sm.OLS(y,X0).fit()
#OLS Ordinary List square regression 
result.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   size   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Tue, 14 Jun 2022   Prob (F-statistic):           8.13e-31
# Time:                        07:18:34   Log-Likelihood:                -642.81
# No. Observations:                 100   AIC:                             1290.
# Df Residuals:                      98   BIC:                             1295.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
sns.set()
# Create a scatter plot
plt.scatter(x1,y)
# Define the regression equation, so we can plot it later
yhat = 0.0033*x1 + -122.3349
# Plot the regression line against the independent variable (SAT)
plt.plot(x1,yhat, lw=1, c='orange', label ='regression line')
# Label the axes
plt.xlabel('Size',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
data.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
x= data['SAT']
y= data['GPA']
x.head()
# Out:
# 0    1714
# 1    1664
# 2    1760
# 3    1685
# 4    1693
# Name: SAT, dtype: int64

# %%
reg = LinearRegression()

# %%
reg.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b8797431b3c6> in <module>()
# ----> 1 reg.fit(x,y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     661
#     662         X, y = self._validate_data(
# --> 663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#     665
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %% [markdown]
# Here we can see the error Error for Dimention
# Dimention of the normal x is 1D
# If you do x.shape() => (84,)
# Now we want 2D without Harming data
# x_matrix = x.values.reshape(84,1)

# %%
x_matrix = x.values.reshape(84,1) 
y_matrix = y.values.reshape(84,1)

# %%
reg.fit(x_matrix,y_matrix)
# Out:
# LinearRegression()

# %%
# R square
reg.score(x_matrix,y_matrix)
# Out:
# 0.40600391479679754

# %%
reg.coef_
# Out:
# array([[0.00165569]])

# %%
reg.intercept_
# Out:
# array([0.2750403])

# %%
dataf = pd.DataFrame(data=[1720,1740], columns=['SAT'])
dataf
# Out:
#     SAT
# 0  1720
# 1  1740

# %%
reg.predict(dataf)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# array([[3.12282375],
#        [3.15593751]])

# %%
Irisdata = pd.read_csv("/gdrive/MyDrive/DataScience_Stuff/iris_dataset.csv")
Irisdata
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.cluster import KMeans

# %%
sns.set()
plt.scatter(Irisdata['sepal_length'], Irisdata['sepal_width'])
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.show()

# %%
x= Irisdata.copy()

kmeans= KMeans(2)

kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# Clustring without scaling

# %%
cluster = Irisdata.copy()
cluster['cluster_predict']= kmeans.fit_predict(x)

# %%
plt.scatter(cluster['sepal_length'], cluster['sepal_width'], c=cluster['cluster_predict'], cmap='rainbow')

# %% [markdown]
# Clustring with scaling

# %%
from sklearn import preprocessing

x_scaled = preprocessing.scale(Irisdata)
x_scaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
kmeans_scaled = KMeans(2)
kmeans_scaled.fit(x_scaled)
# Out:
# KMeans(n_clusters=2)

# %%
scalecluster = Irisdata.copy()
scalecluster['cluster_predict']= kmeans_scaled.fit_predict(x_scaled)

# %%
plt.scatter(scalecluster['sepal_length'], scalecluster['sepal_width'], c=scalecluster['cluster_predict'], cmap='rainbow')

# %%
wcss = []
cl_num = 10
for i in range (1,cl_num):
    kmeans= KMeans(i)
    kmeans.fit(x_scaled)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
wcss
# Out:
# [600.0,
#  223.73200573676345,
#  140.96581663074699,
#  114.57790500611006,
#  91.06677122728534,
#  80.23060704506955,
#  72.28773393630959,
#  62.595620409227735,
#  54.64612561783832]

# %%
number_clusters = range(1,cl_num)
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %% [markdown]
# **Deep Learning With and Without using TenserFlow**
#
# *Without Using tenser flow*

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
#How many data we are generating
observation = 1000

#Data generation 
x=np.random.uniform(-10,10,(observation,1))
z=np.random.uniform(-10,10,(observation,1))

input = np.column_stack((x,z))
input.shape
# Out:
# (1000, 2)

# %%
#As we know every data having some noice
noice=np.random.uniform(-1,1,(observation,1))

#Now we create target
#In this way, we are basically saying: the weights should be 2 and -3, while the bias is 5.
target = 2*x - 3*z + 5 + noice  

target.shape
# Out:
# (1000, 1)

# %%
target = target.reshape(observation,)
#Plotting
fig= plt.figure()

ax = fig.add_subplot(111, projection='3d')

ax.plot(x, z, target)

ax.set_xlabel('x')
ax.set_ylabel('z')
ax.set_zlabel('Targets')

ax.view_init(azim=30)

plt.show()

target = target.reshape(observation,1)

# %%
init_range = 0.1

# Weights are of size k x m, where k is the number of input variables and m is the number of output variables
# In our case, the weights matrix is 2x1 since there are 2 inputs (x and z) and one output (y)
weights = np.random.uniform(low=-init_range, high=init_range, size=(2, 1))

# Biases are of size 1 since there is only 1 output. The bias is a scalar.
biases = np.random.uniform(low=-init_range, high=init_range, size=1)

#Print the weights to get a sense of how they were initialized.
print (weights)
print (biases)
# Out:
# [[-0.01952587]
#  [-0.0706004 ]]
# [-0.06145563]

# %%
#set learning rate
learning_rate = 0.02

# %%
#Training model

for i in range(10000):
  #Formula y= xw +b
  output = np.dot(input,weights)+biases
  #Delta is diffrence bt o/p target
  deltas=output-target

  # We are considering the L2-norm loss, but divided by 2, so it is consistent with the lectures.
  loss = np.sum(deltas ** 2)/2/observation

  print("Loss : "+str(loss))

  deltas_scaled = deltas / observation
  weights = weights - learning_rate * np.dot(input.T,deltas_scaled)
  biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# Loss : 0.16866821166394216
# ...

# %%
# We print the weights and the biases, so we can see if they have converged to what we wanted.
# When declared the targets, following the f(x,z), we knew the weights should be 2 and -3, while the bias: 5.
print (weights, biases)
# Out:
# [[ 1.9982487 ]
#  [-2.99999945]] [4.99279516]

# %%
plt.plot(output,target)
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()

# %% [markdown]
# *With Tensorflow*

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
observations = 100000

# We will work with two variables as inputs. You can think about them as x1 and x2 in our previous examples.
# We have picked x and z, since it is easier to differentiate them.
# We generate them randomly, drawing from an uniform distribution. There are 3 arguments of this method (low, high, size).
# The size of xs and zs is observations x 1. In this case: 1000 x 1.
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(-10, 10, (observations,1))

# Combine the two dimensions of the input into one input matrix. 
# This is the X matrix from the linear model y = x*w + b.
# column_stack is a Numpy method, which combines two matrices (vectors) into one.
generated_inputs = np.column_stack((xs,zs))

# We add a random small noise to the function i.e. f(x,z) = 2x - 3z + 5 + <small noise>
noise = np.random.uniform(-1, 1, (observations,1))

# Produce the targets according to our f(x,z) = 2x - 3z + 5 + noise definition.
# In this way, we are basically saying: the weights should be 2 and -3, while the bias is 5.
generated_targets = 2*xs - 3*zs + 5 + noise

# save into an npz file called "TF_intro"
np.savez('TF_intro', inputs=generated_inputs, targets=generated_targets)

# %%
# Load the training data from the NPZ
training_data = np.load('TF_intro.npz')

# %%
# Declare a variable where we will store the input size of our model
# It should be equal to the number of variables you have
input_size = 2
# Declare the output size of the model
# It should be equal to the number of outputs you've got (for regressions that's usually 1)
output_size = 1

# Outline the model
# We lay out the model in 'Sequential'
# Note that there are no calculations involved - we are just describing our network
model = tf.keras.Sequential([
                            # Each 'layer' is listed here
                            # The method 'Dense' indicates, our mathematical operation to be (xw + b)
                            tf.keras.layers.Dense(output_size,
                                                 # there are extra arguments you can include to customize your model
                                                 # in our case we are just trying to create a solution that is 
                                                 # as close as possible to our NumPy model
                                                 kernel_initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1),
                                                 bias_initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1)
                                                 )
                            ])

# We can also define a custom optimizer, where we can specify the learning rate
custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
# Note that sometimes you may also need a custom loss function 
# That's much harder to implement and won't be covered in this course though

# 'compile' is the place where you select and indicate the optimizers and the loss
model.compile(optimizer=custom_optimizer, loss='mean_squared_error')

# finally we fit the model, indicating the inputs and targets
# if they are not otherwise specified the number of epochs will be 1 (a single epoch of training), 
# so the number of epochs is 'kind of' mandatory, too
# we can play around with verbose; we prefer verbose=2
model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=1)
# Out:
# 3125/3125 [==============================] - 4s 1ms/step - loss: 0.3744
# Epoch 21/100
# 3125/3125 [==============================] - 4s 1ms/step - loss: 0.3806
# Epoch 22/100
# 1355/3125 [============>.................] - ETA: 2s - loss: 0.3799
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-cbd411f6cdb3> in <module>()
#      33 # so the number of epochs is 'kind of' mandatory, too
#      34 # we can play around with verbose; we prefer verbose=2
# ---> 35 model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=1)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
# ...

# %%
# Extracting the weights and biases is achieved quite easily
model.layers[0].get_weights()
# Out:
# [array([[ 2.0279062],
#         [-3.0109856]], dtype=float32), array([5.006873], dtype=float32)]

# %%
weights = model.layers[0].get_weights()[0]
weights
# Out:
# array([[ 2.0279062],
#        [-3.0109856]], dtype=float32)

# %%
bias = model.layers[0].get_weights()[1]
bias
# Out:
# array([5.006873], dtype=float32)

# %%
model.predict_on_batch(training_data['inputs']).round(1)
# Out:
# array([[  2.7],
#        [  9.3],
#        [ 28.2],
#        ...,
#        [ 51.7],
#        [ 24.9],
#        [-38.6]], dtype=float32)

# %%
# If we display our targets (actual observed values), we can manually compare the outputs and the targets
training_data['targets'].round(1)
# Out:
# array([[  2.9],
#        [  9.9],
#        [ 28.7],
#        ...,
#        [ 51.6],
#        [ 24.9],
#        [-37.4]])
